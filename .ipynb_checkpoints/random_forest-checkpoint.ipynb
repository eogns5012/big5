# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
def plot_decision_region(X, y, classifier, test_idx = None, resolution = 0.02, title = ""):
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('r', 'b', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.mestgrid(np.arange(x1_min, x1_max, resolution),
                        np.arenge(x2_min, x2_max, resolution))
    
    Z = classifier.predict(np.array([xx.ravel(), yy.ravel()]).T)
    Z = Z.reshape(xx.shape)
    
    plt.contourf(xx, yy, Z, alpha = .5, cmap = cmap)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    X_test, y_test = X[test_idx, :], y[test_idx]

# %%
big5_sc = pd.read_csv('./big5_scored.csv')

# %%
big5_sc
# Out:
#        E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  ...  O6  O7  O8  O9  O10  \
# 0       4   4   5   4   5   5   4   3   5    5  ...   5   4   2   5    5
# 1       2   4   3   3   3   3   1   1   1    1  ...   3   3   1   3    2
# 2       5   5   1   2   5   5   1   1   5    5  ...   5   5   5   5    5
# 3       2   1   2   2   3   2   3   2   4    1  ...   4   5   2   5    5
# 4       3   5   3   3   3   5   3   5   3    1  ...   5   3   1   5    3
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ..  ..  ..  ..  ...
# 19714   1   2   3   1   4   3   1   4   1    1  ...   5   4   2   5    3
# 19715   2   3   2   3   2   3   2   2   4    2  ...   3   4   2   3    3
# 19716   2   1   4   1   5   1   1   4   1    1  ...   5   1   5   5    5
# 19717   1   2   2   3   2   2   1   3   4    1  ...   5   5   3   5    5
# 19718   2   3   1   1   3   3   3   4   2    2  ...   5   5   5   5    5
#
#        E_SC  N_SC  A_SC  C_SC  O_SC
# 0        44    49    46    47    43
# ...

# %%
E = big5_sc.loc[:, "E1":"E10"]

# %%
E.loc[:,"score"] = big5_sc.loc[:,"E_SC"]
# Out:
# C:\Users\ajou\AppData\Local\Temp\ipykernel_15580\3466361353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E.loc[:,"score"] = big5_sc.loc[:,"E_SC"]

# %%
E
# Out:
#        E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  score
# 0       4   4   5   4   5   5   4   3   5    5     44
# 1       2   4   3   3   3   3   1   1   1    1     22
# 2       5   5   1   2   5   5   1   1   5    5     35
# 3       2   1   2   2   3   2   3   2   4    1     22
# 4       3   5   3   3   3   5   3   5   3    1     34
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...    ...
# 19714   1   2   3   1   4   3   1   4   1    1     21
# 19715   2   3   2   3   2   3   2   2   4    2     25
# 19716   2   1   4   1   5   1   1   4   1    1     21
# 19717   1   2   2   3   2   2   1   3   4    1     21
# 19718   2   3   1   1   3   3   3   4   2    2     24
#
# [19719 rows x 11 columns]

# %%
classifier = RandomForestClassifier(n_estimators = 1000)

# %%
train_X, train_y = E.iloc[:int(len(E.index)*0.8), :-1], E.iloc[:int(len(E.index)*0.8), -1]
test_X, test_y = E.iloc[int(len(E.index)*0.8):, :-1], E.iloc[int(len(E.index)*0.8):, -1]

# %%
classifier.fit(train_X, train_y)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
score = classifier.score(test_X, test_y)
print(score)
# Out:
# 0.3496450304259635

# %%
y_pred = classifier.predict(test_X)
print('총 테스트 개수 : %d, 오류개수 : %d' %(len(test_y), (test_y != y_pred).sum()))
print('정확도 : %.2f' %((test_y) != y_pred).sum() / len(test_y))
# Out:
# 총 테스트 개수 : 3944, 오류개수 : 2565
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15580\3236153913.py in <module>
#       1 y_pred = classifier.predict(test_X)
#       2 print('총 테스트 개수 : %d, 오류개수 : %d' %(len(test_y), (test_y != y_pred).sum()))
# ----> 3 print('정확도 : %.2f' %((test_y) != y_pred).sum() / len(test_y))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
X_combined = np.vstack((train_X, test_X))
y_combined = np.hstack((train_y, test_y))

plot_decision_region(X = X_combined, y = y_combined, classifier= classifier,
                    test_idx = range(10, 50), title = "RF for E")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15580\1689640150.py in <module>
#       2 y_combined = np.hstack((train_y, test_y))
#       3
# ----> 4 plot_decision_region(X = X_combined, y = y_combined, classifier= classifier,
#       5                     test_idx = range(10, 50), title = "RF for E")
#
# NameError: name 'plot_decision_region' is not defined

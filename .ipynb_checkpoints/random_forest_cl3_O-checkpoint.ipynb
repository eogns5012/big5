# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.ensemble import RandomForestClassifier

# %%
big5_sc = pd.read_csv('./big5_scored.csv')

# %%
big5_sc
# Out:
#        E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  ...  O6  O7  O8  O9  O10  \
# 0       4   4   5   4   5   5   4   3   5    5  ...   5   4   2   5    5
# 1       2   4   3   3   3   3   1   1   1    1  ...   3   3   1   3    2
# 2       5   5   1   2   5   5   1   1   5    5  ...   5   5   5   5    5
# 3       2   1   2   2   3   2   3   2   4    1  ...   4   5   2   5    5
# 4       3   5   3   3   3   5   3   5   3    1  ...   5   3   1   5    3
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ..  ..  ..  ..  ...
# 19714   1   2   3   1   4   3   1   4   1    1  ...   5   4   2   5    3
# 19715   2   3   2   3   2   3   2   2   4    2  ...   3   4   2   3    3
# 19716   2   1   4   1   5   1   1   4   1    1  ...   5   1   5   5    5
# 19717   1   2   2   3   2   2   1   3   4    1  ...   5   5   3   5    5
# 19718   2   3   1   1   3   3   3   4   2    2  ...   5   5   5   5    5
#
#        E_SC  N_SC  A_SC  C_SC  O_SC
# 0        44    49    46    47    43
# 1        22    29    35    42    26
# 2        35    14    38    49    45
# 3        22    17    37    26    41
# 4        34    30    44    34    34
# ...     ...   ...   ...   ...   ...
# 19714    21    19    42    36    35
# 19715    25    39    36    32    30
# 19716    21    10    26    23    37
# 19717    21    20    38    43    42
# 19718    24    23    35    36    49
#
# [19719 rows x 55 columns]

# %%
O = big5_sc.loc[:, "O1":"O10"]

# %%
O.loc[:,"score"] = big5_sc.loc[:,"O_SC"]
# Out:
# C:\Users\ajou\AppData\Local\Temp\ipykernel_11244\1650376474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O.loc[:,"score"] = big5_sc.loc[:,"O_SC"]

# %%
O
# Out:
#        O1  O2  O3  O4  O5  O6  O7  O8  O9  O10  score
# 0       4   5   3   5   5   5   4   2   5    5     43
# 1       3   3   3   3   2   3   3   1   3    2     26
# 2       4   1   5   5   5   5   5   5   5    5     45
# 3       4   3   5   4   4   4   5   2   5    5     41
# 4       3   5   1   5   3   5   3   1   5    3     34
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...    ...
# 19714   1   3   5   3   4   5   4   2   5    3     35
# 19715   1   4   3   4   3   3   4   2   3    3     30
# 19716   5   3   1   3   4   5   1   5   5    5     37
# 19717   3   4   5   3   4   5   5   3   5    5     42
# 19718   5   5   5   5   4   5   5   5   5    5     49
#
# [19719 rows x 11 columns]

# %%
categorys = []
for val in O['score']:
    if val < 30:
        category = 0
    else:
        category = 1
    categorys.append(category)
    
O['C'] = categorys
# Out:
# C:\Users\ajou\AppData\Local\Temp\ipykernel_11244\3419928540.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   O['C'] = categorys

# %%
O
# Out:
#        O1  O2  O3  O4  O5  O6  O7  O8  O9  O10  score  C
# 0       4   5   3   5   5   5   4   2   5    5     43  1
# 1       3   3   3   3   2   3   3   1   3    2     26  0
# 2       4   1   5   5   5   5   5   5   5    5     45  1
# 3       4   3   5   4   4   4   5   2   5    5     41  1
# 4       3   5   1   5   3   5   3   1   5    3     34  1
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...    ... ..
# 19714   1   3   5   3   4   5   4   2   5    3     35  1
# 19715   1   4   3   4   3   3   4   2   3    3     30  1
# 19716   5   3   1   3   4   5   1   5   5    5     37  1
# 19717   3   4   5   3   4   5   5   3   5    5     42  1
# 19718   5   5   5   5   4   5   5   5   5    5     49  1
#
# [19719 rows x 12 columns]

# %%
O_train_X, O_train_y = O.iloc[:int(len(O.index)*0.8), :-2], O.iloc[:int(len(O.index)*0.8), -1]
O_test_X, O_test_y = O.iloc[int(len(O.index)*0.8):, :-2], O.iloc[int(len(O.index)*0.8):, -1]
O_test_X = O_test_X.reset_index(drop=True)

# %%
O_classifier = RandomForestClassifier(n_estimators = 10, random_state = 0)
O_classifier.fit(O_train_X, O_train_y)

O_train_score = O_classifier.score(O_train_X, O_train_y)
print(O_train_score)

O_score = O_classifier.score(O_test_X, O_test_y)
print(O_score)
# Out:
# 0.9997464342313788
# 0.978448275862069

# %%
O_train_y_pred = O_classifier.predict(O_train_X)
print('총 학습 개수 : %d, 오류개수 : %d' %(len(O_train_y), (O_train_y != O_train_y_pred).sum()))
print('정확도 : %.2f' %((len(O_train_y) - (O_train_y != O_train_y_pred).sum()) / len(O_train_y)))
# Out:
# 총 학습 개수 : 15775, 오류개수 : 4
# 정확도 : 1.00

# %%
O_y_pred = O_classifier.predict(O_test_X)
print('총 테스트 개수 : %d, 오류개수 : %d' %(len(O_test_y), (O_test_y != O_y_pred).sum()))
print('정확도 : %.2f' %((len(O_test_y) - (O_test_y != O_y_pred).sum()) / len(O_test_y)))
# Out:
# 총 테스트 개수 : 3944, 오류개수 : 85
# 정확도 : 0.98

# %%
importances = O_classifier.feature_importances_
std = np.std([tree.feature_importances_ for tree in O_classifier.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print("feature ranking:")

for f in range(len(O_train_X.columns)):
    print("{}. feature {} ({:.3f})".format(f+1, O_train_X.columns[indices][f], importances[indices[f]]))
    
plt.figure()
plt.title("Feature importances")
plt.bar(range(len(O_train_X.columns)), importances[indices],
       color = "r", yerr = std[indices], align = "center")
plt.xticks(range(len(O_train_X.columns)), O_train_X.columns[indices], rotation = 45)
plt.xlim([-1, len(O_train_X.columns)])
plt.show()
# Out:
# feature ranking:
# 1. feature O10 (0.195)
# 2. feature O1 (0.124)
# 3. feature O6 (0.104)
# 4. feature O2 (0.103)
# 5. feature O5 (0.084)
# 6. feature O4 (0.081)
# 7. feature O7 (0.081)
# 8. feature O3 (0.079)
# 9. feature O8 (0.078)
# 10. feature O9 (0.072)

# %%
random.seed(0)
shuffled_scores = {}

for feature in O_train_X.columns:
    copy = O_train_X.copy()
    random.shuffle(copy.loc[:, feature])
    
    shuffled_score = O_classifier.score(copy, O_train_y)
    shuffled_scores[feature] = shuffled_score

print(shuffled_scores)
# Out:
# {'O1': 0.9755309033280507, 'O2': 0.9760380348652932, 'O3': 0.9838985736925515, 'O4': 0.9823137876386688, 'O5': 0.9867511885895404, 'O6': 0.9802218700475436, 'O7': 0.9851664025356577, 'O8': 0.9832012678288431, 'O9': 0.9853565768621236, 'O10': 0.9721711568938194}

# %%
print("Original Classfication Accuracy : %.4f"%O_train_score)
for n in range(len(O_train_X.columns)):
    print("%s high importance shuffled Accuracy : %.4f" %(n+1, shuffled_scores[O_train_X.columns[indices][n]]))
# Out:
# Original Classfication Accuracy : 0.9997
# 1 high importance shuffled Accuracy : 0.9722
# 2 high importance shuffled Accuracy : 0.9755
# 3 high importance shuffled Accuracy : 0.9802
# 4 high importance shuffled Accuracy : 0.9760
# 5 high importance shuffled Accuracy : 0.9868
# 6 high importance shuffled Accuracy : 0.9823
# 7 high importance shuffled Accuracy : 0.9852
# 8 high importance shuffled Accuracy : 0.9839
# 9 high importance shuffled Accuracy : 0.9832
# 10 high importance shuffled Accuracy : 0.9854

# %%
random.seed(0)
shuffled_scores = {}

for feature in O_test_X.columns:
    copy = O_test_X.copy()
    random.shuffle(copy.loc[:, feature])
    
    shuffled_score = O_classifier.score(copy, O_test_y)
    shuffled_scores[feature] = shuffled_score

print(shuffled_scores)
# Out:
# {'O1': 0.9601926977687627, 'O2': 0.960446247464503, 'O3': 0.9693204868154158, 'O4': 0.9645030425963489, 'O5': 0.9723630831643002, 'O6': 0.9629817444219066, 'O7': 0.968052738336714, 'O8': 0.9675456389452333, 'O9': 0.967292089249493, 'O10': 0.9601926977687627}

# %%
print("Original Classfication Accuracy : %.4f"%O_score)
for n in range(len(O_train_X.columns)):
    print("%s high importance shuffled Accuracy : %.4f" %(n+1, shuffled_scores[O_train_X.columns[indices][n]]))
# Out:
# Original Classfication Accuracy : 0.9784
# 1 high importance shuffled Accuracy : 0.9602
# 2 high importance shuffled Accuracy : 0.9602
# 3 high importance shuffled Accuracy : 0.9630
# 4 high importance shuffled Accuracy : 0.9604
# 5 high importance shuffled Accuracy : 0.9724
# 6 high importance shuffled Accuracy : 0.9645
# 7 high importance shuffled Accuracy : 0.9681
# 8 high importance shuffled Accuracy : 0.9693
# 9 high importance shuffled Accuracy : 0.9675
# 10 high importance shuffled Accuracy : 0.9673

# %%
O2_se_train_X = O_train_X.copy()
O2_se_train_X = O2_se_train_X.loc[:, ["O10", "O1"]]

O2_se_test_X = O_test_X.copy()
O2_se_test_X = O2_se_test_X.loc[:, ["O10", "O1"]]
O2_se_test_X = O2_se_test_X.reset_index(drop=True)

O2_se_classifier = RandomForestClassifier(n_estimators = 10, random_state=0)
O2_se_classifier.fit(O2_se_train_X, O_train_y)

O2_se_score = O2_se_classifier.score(O2_se_train_X, O_train_y)
print(O2_se_score)

O2_se_test_score = O2_se_classifier.score(O2_se_test_X, O_test_y)
print(O2_se_test_score)
# Out:
# 0.9452931854199683
# 0.9419371196754563

# %%
O3_se_train_X = O_train_X.copy()
O3_se_train_X = O3_se_train_X.loc[:, ["O10", "O1","O6"]]

O3_se_test_X = O_test_X.copy()
O3_se_test_X = O3_se_test_X.loc[:, ["O10", "O1","O6"]]
O3_se_test_X = O3_se_test_X.reset_index(drop=True)

O3_se_classifier = RandomForestClassifier(n_estimators = 10, random_state=0)
O3_se_classifier.fit(O3_se_train_X, O_train_y)

O3_se_score = O3_se_classifier.score(O3_se_train_X, O_train_y)
print(O3_se_score)

O3_se_test_score = O3_se_classifier.score(O3_se_test_X, O_test_y)
print(O3_se_test_score)
# Out:
# 0.9540412044374009
# 0.9485294117647058

# %%
O4_se_train_X = O_train_X.copy()
O4_se_train_X = O4_se_train_X.loc[:, ["O10", "O1","O6","O2"]]

O4_se_test_X = O_test_X.copy()
O4_se_test_X = O4_se_test_X.loc[:, ["O10", "O1","O6","O2"]]
O4_se_test_X = O4_se_test_X.reset_index(drop=True)

O4_se_classifier = RandomForestClassifier(n_estimators = 10, random_state=0)
O4_se_classifier.fit(O4_se_train_X, O_train_y)

O4_se_score = O4_se_classifier.score(O4_se_train_X, O_train_y)
print(O4_se_score)

O4_se_test_score = O4_se_classifier.score(O4_se_test_X, O_test_y)
print(O4_se_test_score)
# Out:
# 0.9646275752773376
# 0.9538539553752535

# %%
O5_se_train_X = O_train_X.copy()
O5_se_train_X = O5_se_train_X.loc[:, ["O10", "O1","O6","O2","O5"]]

O5_se_test_X = O_test_X.copy()
O5_se_test_X = O5_se_test_X.loc[:, ["O10", "O1","O6","O2","O5"]]
O5_se_test_X = O5_se_test_X.reset_index(drop=True)

O5_se_classifier = RandomForestClassifier(n_estimators = 10, random_state=0)
O5_se_classifier.fit(O5_se_train_X, O_train_y)

O5_se_score = O5_se_classifier.score(O5_se_train_X, O_train_y)
print(O5_se_score)

O5_se_test_score = O5_se_classifier.score(O5_se_test_X, O_test_y)
print(O5_se_test_score)
# Out:
# 0.9726782884310619
# 0.9543610547667343

# %% [markdown]
# 4~5
